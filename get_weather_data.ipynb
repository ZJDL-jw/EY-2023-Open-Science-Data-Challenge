# %%
import planetary_computer
import pystac_client
import xarray as xr
import fsspec
import numpy as np
import pandas as pd

# %%
## 可能需要安装以下组件以免报错：
# pip install aiohttp
# pip install h5netcdf

# %%
## Loading initial data
## SA有257个，WS有300个
data = pd.read_csv('Training_data_SA.csv')
data
# Out:
#       District   Latitude   Longitude  \
# 0     Chau_Phu  10.510542  105.248554
# 1     Chau_Phu  10.509150  105.265098
# 2     Chau_Phu  10.467721  105.192464
# 3     Chau_Phu  10.494453  105.241281
# 4     Chau_Phu  10.535058  105.252744
# ..         ...        ...         ...
# 252  Thoai_Son  10.364419  105.164984
# 253  Thoai_Son  10.358727  105.222371
# 254  Thoai_Son  10.358094  105.189541
# 255  Thoai_Son  10.368014  105.238516
# 256  Thoai_Son  10.365734  105.267634
#
#     Season(SA = Summer Autumn, WS = Winter Spring)  \
# 0                                               SA
# 1                                               SA
# 2                                               SA
# 3                                               SA
# 4                                               SA
# ..                                             ...
# 252                                             SA
# 253                                             SA
# 254                                             SA
# 255                                             SA
# 256                                             SA
#
#     Rice Crop Intensity(D=Double, T=Triple) Date of Harvest  Field size (ha)  \
# 0                                         T      15-07-2022             3.40
# 1                                         T      15-07-2022             2.43
# 2                                         D      15-07-2022             1.95
# 3                                         T      15-07-2022             4.30
# 4                                         D      14-07-2022             3.30
# ..                                      ...             ...              ...
# 252                                       T      12-07-2022             7.80
# 253                                       T      21-07-2022             2.00
# 254                                       T      21-07-2022             2.00
# 255                                       T      21-07-2022             6.20
# 256                                       T      21-07-2022             2.50
#
#      Rice Yield (kg/ha)
# 0                  5500
# 1                  6000
# 2                  6400
# 3                  6000
# 4                  6400
# ..                  ...
# 252                5600
# 253                5600
# 254                5600
# 255                5600
# 256                5600
#
# [257 rows x 8 columns]

# %%
catalog = pystac_client.Client.open(
        "https://planetarycomputer.microsoft.com/api/stac/v1",
        modifier=planetary_computer.sign_inplace,
)

# %%
def get_bbox(lat: float, long: float, box_size_ha: float = 4):

    box_size_deg = box_size_ha * .001 * 0.98480775

    # cos 10° = 0.98480775
    # 1经度在赤道相当于111,000米， 1经度在纬度10°相当于111,000*0.98480775
    # 1公顷相当于100米×100米
    #
    # 对于赤道，图上1.11米相当于0.00001经度， 1公顷相当于0.001经度×0.001经度
    # 对于非赤道，1公顷相当于(0.001经度*cos纬度)×(0.001经度*cos纬度)

    lat_long = (lat, long) # Lat-Lon centroid location
    box_size_deg = box_size_deg # Surrounding box in degrees, yields approximately 5x5 pixel region

    min_lon = lat_long[1]-box_size_deg/2
    min_lat = lat_long[0]-box_size_deg/2
    max_lon = lat_long[1]+box_size_deg/2
    max_lat = lat_long[0]+box_size_deg/2

    bbox = [min_lon, min_lat, max_lon, max_lat]

    return bbox

# %%
def get_time_window(season: str = ['SA', 'WS', 'AW']):
    if season == 'SA':
        time_window = "2022-04-01/2022-08-31" #153天
        start_time = "2022-04-01"
        end_time = "2022-08-31"
    elif season == 'WS':
        time_window = "2021-11-01/2022-04-30" #181天
        start_time = "2021-11-01"
        end_time = "2022-04-30"
    elif season == 'AW':
        time_window = "2022-07-01/2022-12-31"
        start_time = "2022-07-01"
        end_time = "2022-12-31"
    else:
        print(f"{season} is not usable.")

    return time_window, start_time, end_time

# %%
# get items
def get_items(
        time_window: str,
        bbox: list,
        collections: list = ["nasa-nex-gddp-cmip6"],
        query: dict = {"cmip6:model": {"eq": "ACCESS-CM2"},"cmip6:scenario": {"eq": "ssp245"}}):

    search = catalog.search(
    collections = collections,
    datetime = time_window,
    bbox = bbox,
    query = query
    )

    items = search.get_all_items()
    print(f"Found {len(items)} items.")

    return items

# %%
# %%time
#Load_data —— containing 9 variables:

# hurs (Description: Near-Surface Relative Humidity, Unit:%)
# huss (Description: Near-Surface Specific Humidity, Unit:1)
# pr (Description: Precipitation, Unit:kg/(m2*s))
# rlds (Description: Surface Downwelling Longwave Radiation, Unit:W/m2)
# rsds (Description: Surface Downwelling Shortwave Radiation, Unit:W/m2),
# sfcwind (Description: Daily-Mean Near-Surface Wind Speed, Unit:m*s),
# tas (Description: Daily Near-Surface Air Temperature, Unit:K),
# tasmax (Description: Daily Maximum Near-Surface Air Temperature, Unit:K),
# tasmin (Description: Daily Minimum Near-Surface Air Temperature, Unit:K)

variables = ["hurs","huss","pr","rlds","rsds","sfcWind","tas","tasmax","tasmin"]

#Produce a three-dimentional array to load the time-series-mean results of 9 variables for SA and WS respectively
timeseries_SA = np.zeros((257,153,9), dtype=float) #数组的三个维度分别代表 样本序号、日期、气候变量
timeseries_WS = np.zeros((300,181,9), dtype=float)

for i in range(len(data)):

    bbox = get_bbox(data['Latitude'][i], data['Longitude'][i], data['Field size (ha)'][i])
    time_window, start_time, end_time = get_time_window(data['Season(SA = Summer Autumn, WS = Winter Spring)'][i])
    items = get_items(time_window,bbox,)
    tgt_lat = xr.DataArray(np.arange(bbox[1],bbox[3],0.25)) #经纬度范围，一个像素点单位为 0.25 经纬度
    tgt_log = xr.DataArray(np.arange(bbox[0],bbox[2],0.25))

    for var in variables:
        exec("%s_ds = xr.open_mfdataset([fsspec.open(item.assets[var].href).open() for item in items],)" %var)
        exec("%s_da = %s_ds[var]" %(var,var))
        exec("%s_da = %s_da.loc[start_time:end_time]" %(var,var))
        exec("%s_da = %s_da.sel(**{'lat': slice(0.25*int((bbox[1]+59.875)/0.25)-59.875,0.25*int((bbox[3]+59.875)/0.25)-59.875), 'lon': slice(0.25*int((bbox[0]-0.125)/0.25)+0.125,0.25*int((bbox[2]-0.125)/0.25)+0.125)})" %(var,var)) ##四舍五入处理以满足要求
        exec("%s_mean = %s_da.groupby('time').mean(dim=['lat','lon']).values" %(var,var))
        exec("%s_mean = np.reshape(%s_mean,(-1,1))" %(var,var))

    ## exec("sample_%s = np.concatenate((hurs_da.values,huss_da.values,pr_da.values,rlds_da.values,rsds_da.values,sfcWind_da.values,tas_da.values,tasmax_da.values,tasmin_da.values),axis=1)"%i)
    
    temp = np.concatenate((hurs_mean,huss_mean,pr_mean,rlds_mean,rsds_mean,sfcWind_mean,tas_mean,tasmax_mean,tasmin_mean),axis=1)

    if data['Season(SA = Summer Autumn, WS = Winter Spring)'][i] == 'SA':
        timeseries_SA[i,:,:] = temp

    else:
        timeseries_WS[i,:,:] = temp

    print(f"the {i+1}th/{len(data)} sample is accomplished")
# Out:
# Found 1 items.
# the 1th/257 sample is accomplished
# Found 1 items.
# the 2th/257 sample is accomplished
# Found 1 items.
# the 3th/257 sample is accomplished
# Found 1 items.
# the 4th/257 sample is accomplished
# Found 1 items.
# the 5th/257 sample is accomplished
# Found 1 items.
# the 6th/257 sample is accomplished
# Found 1 items.
# the 7th/257 sample is accomplished
# Found 1 items.
# the 8th/257 sample is accomplished
# Found 1 items.
# the 9th/257 sample is accomplished
# Found 1 items.
# the 10th/257 sample is accomplished
# Found 1 items.
# the 11th/257 sample is accomplished
# Found 1 items.
# the 12th/257 sample is accomplished
# Found 1 items.
# the 13th/257 sample is accomplished
# Found 1 items.
# the 14th/257 sample is accomplished
# Found 1 items.
# the 15th/257 sample is accomplished
# Found 1 items.
# the 16th/257 sample is accomplished
# Found 1 items.
# the 17th/257 sample is accomplished
# Found 1 items.
# the 18th/257 sample is accomplished
# Found 1 items.
# the 19th/257 sample is accomplished
# Found 1 items.
# the 20th/257 sample is accomplished
# Found 1 items.
# the 21th/257 sample is accomplished
# Found 1 items.
# the 22th/257 sample is accomplished
# Found 1 items.
# the 23th/257 sample is accomplished
# Found 1 items.
# the 24th/257 sample is accomplished
# Found 1 items.
# the 25th/257 sample is accomplished
# Found 1 items.
# the 26th/257 sample is accomplished
# Found 1 items.
# the 27th/257 sample is accomplished
# Found 1 items.
# the 28th/257 sample is accomplished
# Found 1 items.
# the 29th/257 sample is accomplished
# Found 1 items.
# the 30th/257 sample is accomplished
# Found 1 items.
# the 31th/257 sample is accomplished
# Found 1 items.
# the 32th/257 sample is accomplished
# Found 1 items.
# the 33th/257 sample is accomplished
# Found 1 items.
# the 34th/257 sample is accomplished
# Found 1 items.
# the 35th/257 sample is accomplished
# Found 1 items.
# the 36th/257 sample is accomplished
# Found 1 items.
# the 37th/257 sample is accomplished
# Found 1 items.
# the 38th/257 sample is accomplished
# Found 1 items.
# the 39th/257 sample is accomplished
# Found 1 items.
# the 40th/257 sample is accomplished
# Found 1 items.
# the 41th/257 sample is accomplished
# Found 1 items.
# the 42th/257 sample is accomplished
# Found 1 items.
# the 43th/257 sample is accomplished
# Found 1 items.
# the 44th/257 sample is accomplished
# Found 1 items.
# the 45th/257 sample is accomplished
# Found 1 items.
# the 46th/257 sample is accomplished
# Found 1 items.
# the 47th/257 sample is accomplished
# Found 1 items.
# the 48th/257 sample is accomplished
# Found 1 items.
# the 49th/257 sample is accomplished
# Found 1 items.
# the 50th/257 sample is accomplished
# Found 1 items.
# the 51th/257 sample is accomplished
# Found 1 items.
# the 52th/257 sample is accomplished
# Found 1 items.
# the 53th/257 sample is accomplished
# Found 1 items.
# the 54th/257 sample is accomplished
# Found 1 items.
# the 55th/257 sample is accomplished
# Found 1 items.
# the 56th/257 sample is accomplished
# Found 1 items.
# the 57th/257 sample is accomplished
# Found 1 items.
# the 58th/257 sample is accomplished
# Found 1 items.
# the 59th/257 sample is accomplished
# Found 1 items.
# the 60th/257 sample is accomplished
# Found 1 items.
# the 61th/257 sample is accomplished
# Found 1 items.
# the 62th/257 sample is accomplished
# Found 1 items.
# the 63th/257 sample is accomplished
# Found 1 items.
# the 64th/257 sample is accomplished
# Found 1 items.
# the 65th/257 sample is accomplished
# Found 1 items.
# the 66th/257 sample is accomplished
# Found 1 items.
# the 82th/257 sample is accomplished
# Found 1 items.
# the 83th/257 sample is accomplished
# Found 1 items.
# the 84th/257 sample is accomplished
# Found 1 items.
# the 85th/257 sample is accomplished
# Found 1 items.
# the 86th/257 sample is accomplished
# Found 1 items.
# the 87th/257 sample is accomplished
# Found 1 items.
# the 88th/257 sample is accomplished
# Found 1 items.
# the 89th/257 sample is accomplished
# Found 1 items.
# the 90th/257 sample is accomplished
# Found 1 items.
# the 91th/257 sample is accomplished
# Found 1 items.
# the 92th/257 sample is accomplished
# Found 1 items.
# the 93th/257 sample is accomplished
# Found 1 items.
# the 94th/257 sample is accomplished
# Found 1 items.
# the 95th/257 sample is accomplished
# Found 1 items.
# the 96th/257 sample is accomplished
# Found 1 items.
# the 97th/257 sample is accomplished
# Found 1 items.
# the 98th/257 sample is accomplished
# Found 1 items.
# the 99th/257 sample is accomplished
# Found 1 items.
# the 100th/257 sample is accomplished
# Found 1 items.
# the 101th/257 sample is accomplished
# Found 1 items.
# the 102th/257 sample is accomplished
# Found 1 items.
# the 103th/257 sample is accomplished
# Found 1 items.
# the 104th/257 sample is accomplished
# Found 1 items.
# the 105th/257 sample is accomplished
# Found 1 items.
# the 106th/257 sample is accomplished
# Found 1 items.
# the 107th/257 sample is accomplished
# Found 1 items.
# the 108th/257 sample is accomplished
# Found 1 items.
# the 109th/257 sample is accomplished
# Found 1 items.
# the 110th/257 sample is accomplished
# Found 1 items.
# the 111th/257 sample is accomplished
# Found 1 items.
# the 112th/257 sample is accomplished
# Found 1 items.
# the 113th/257 sample is accomplished
# Found 1 items.
# the 114th/257 sample is accomplished
# Found 1 items.
# the 115th/257 sample is accomplished
# Found 1 items.
# the 116th/257 sample is accomplished
# Found 1 items.
# the 117th/257 sample is accomplished
# Found 1 items.
# the 118th/257 sample is accomplished
# Found 1 items.
# the 119th/257 sample is accomplished
# Found 1 items.
# the 120th/257 sample is accomplished
# Found 1 items.
# the 121th/257 sample is accomplished
# Found 1 items.
# the 122th/257 sample is accomplished
# Found 1 items.
# the 123th/257 sample is accomplished
# Found 1 items.
# the 124th/257 sample is accomplished
# Found 1 items.
# the 125th/257 sample is accomplished
# Found 1 items.
# the 126th/257 sample is accomplished
# Found 1 items.
# the 127th/257 sample is accomplished
# Found 1 items.
# the 128th/257 sample is accomplished
# Found 1 items.
# the 129th/257 sample is accomplished
# Found 1 items.
# the 130th/257 sample is accomplished
# Found 1 items.
# the 131th/257 sample is accomplished
# Found 1 items.
# the 132th/257 sample is accomplished
# Found 1 items.
# the 133th/257 sample is accomplished
# Found 1 items.
# the 134th/257 sample is accomplished
# Found 1 items.
# the 135th/257 sample is accomplished
# Found 1 items.
# the 136th/257 sample is accomplished
# Found 1 items.
# the 137th/257 sample is accomplished
# Found 1 items.
# the 138th/257 sample is accomplished
# Found 1 items.
# the 139th/257 sample is accomplished
# Found 1 items.
# the 140th/257 sample is accomplished
# Found 1 items.
# the 141th/257 sample is accomplished
# Found 1 items.
# the 142th/257 sample is accomplished
# Found 1 items.
# the 143th/257 sample is accomplished
# Found 1 items.
# the 144th/257 sample is accomplished
# Found 1 items.
# the 145th/257 sample is accomplished
# Found 1 items.
# the 146th/257 sample is accomplished
# Found 1 items.
# the 147th/257 sample is accomplished
# Found 1 items.
# the 148th/257 sample is accomplished
# Found 1 items.
# the 149th/257 sample is accomplished
# Found 1 items.
# the 150th/257 sample is accomplished
# Found 1 items.
# the 151th/257 sample is accomplished
# Found 1 items.
# the 152th/257 sample is accomplished
# Found 1 items.
# the 153th/257 sample is accomplished
# Found 1 items.
# the 154th/257 sample is accomplished
# Found 1 items.
# the 155th/257 sample is accomplished
# Found 1 items.
# the 156th/257 sample is accomplished
# Found 1 items.
# the 157th/257 sample is accomplished
# Found 1 items.
# the 158th/257 sample is accomplished
# Found 1 items.
# the 159th/257 sample is accomplished
# Found 1 items.
# the 160th/257 sample is accomplished
# Found 1 items.
# the 161th/257 sample is accomplished
# Found 1 items.
# the 162th/257 sample is accomplished
# Found 1 items.
# the 163th/257 sample is accomplished
# Found 1 items.
# the 164th/257 sample is accomplished
# Found 1 items.
# the 165th/257 sample is accomplished
# Found 1 items.
# the 166th/257 sample is accomplished
# Found 1 items.
# the 167th/257 sample is accomplished
# Found 1 items.
# the 168th/257 sample is accomplished
# Found 1 items.
# the 169th/257 sample is accomplished
# Found 1 items.
# the 170th/257 sample is accomplished
# Found 1 items.
# the 171th/257 sample is accomplished
# Found 1 items.
# the 172th/257 sample is accomplished
# Found 1 items.
# the 173th/257 sample is accomplished
# Found 1 items.
# the 174th/257 sample is accomplished
# Found 1 items.
# the 175th/257 sample is accomplished
# Found 1 items.
# the 176th/257 sample is accomplished
# Found 1 items.
# the 177th/257 sample is accomplished
# Found 1 items.
# the 178th/257 sample is accomplished
# Found 1 items.
# the 179th/257 sample is accomplished
# Found 1 items.
# the 180th/257 sample is accomplished
# Found 1 items.
# the 181th/257 sample is accomplished
# Found 1 items.
# the 182th/257 sample is accomplished
# Found 1 items.
# the 183th/257 sample is accomplished
# Found 1 items.
# the 184th/257 sample is accomplished
# Found 1 items.
# the 185th/257 sample is accomplished
# Found 1 items.
# the 186th/257 sample is accomplished
# Found 1 items.
# the 187th/257 sample is accomplished
# Found 1 items.
# the 188th/257 sample is accomplished
# Found 1 items.
# the 189th/257 sample is accomplished
# Found 1 items.
# the 190th/257 sample is accomplished
# Found 1 items.
# the 191th/257 sample is accomplished
# Found 1 items.
# the 192th/257 sample is accomplished
# Found 1 items.
# the 193th/257 sample is accomplished
# Found 1 items.
# the 194th/257 sample is accomplished
# Found 1 items.
# the 195th/257 sample is accomplished
# Found 1 items.
# the 196th/257 sample is accomplished
# Found 1 items.
# the 197th/257 sample is accomplished
# Found 1 items.
# the 198th/257 sample is accomplished
# Found 1 items.
# the 199th/257 sample is accomplished
# Found 1 items.
# the 200th/257 sample is accomplished
# Found 1 items.
# the 201th/257 sample is accomplished
# Found 1 items.
# the 202th/257 sample is accomplished
# Found 1 items.
# the 203th/257 sample is accomplished
# Found 1 items.
# the 204th/257 sample is accomplished
# Found 1 items.
# the 205th/257 sample is accomplished
# Found 1 items.
# the 206th/257 sample is accomplished
# Found 1 items.
# the 207th/257 sample is accomplished
# Found 1 items.
# the 208th/257 sample is accomplished
# Found 1 items.
# the 209th/257 sample is accomplished
# Found 1 items.
# the 210th/257 sample is accomplished
# Found 1 items.
# the 211th/257 sample is accomplished
# Found 1 items.
# the 212th/257 sample is accomplished
# Found 1 items.
# the 213th/257 sample is accomplished
# Found 1 items.
# the 214th/257 sample is accomplished
# Found 1 items.
# the 216th/257 sample is accomplished
# Found 1 items.
# the 217th/257 sample is accomplished
# Found 1 items.
# the 218th/257 sample is accomplished
# Found 1 items.
# the 219th/257 sample is accomplished
# Found 1 items.
# the 220th/257 sample is accomplished
# Found 1 items.
# the 221th/257 sample is accomplished
# Found 1 items.
# the 222th/257 sample is accomplished
# Found 1 items.
# the 223th/257 sample is accomplished
# Found 1 items.
# the 224th/257 sample is accomplished
# Found 1 items.
# the 225th/257 sample is accomplished
# Found 1 items.
# the 226th/257 sample is accomplished
# Found 1 items.
# the 227th/257 sample is accomplished
# Found 1 items.
# the 228th/257 sample is accomplished
# Found 1 items.
# the 229th/257 sample is accomplished
# Found 1 items.
# the 230th/257 sample is accomplished
# Found 1 items.
# the 231th/257 sample is accomplished
# Found 1 items.
# the 232th/257 sample is accomplished
# Found 1 items.
# the 233th/257 sample is accomplished
# Found 1 items.
# the 234th/257 sample is accomplished
# Found 1 items.
# the 235th/257 sample is accomplished
# Found 1 items.
# the 236th/257 sample is accomplished
# Found 1 items.
# the 237th/257 sample is accomplished
# Found 1 items.
# the 238th/257 sample is accomplished
# Found 1 items.
# the 239th/257 sample is accomplished
# Found 1 items.
# the 240th/257 sample is accomplished
# Found 1 items.
# the 241th/257 sample is accomplished
# Found 1 items.
# the 242th/257 sample is accomplished
# Found 1 items.
# the 243th/257 sample is accomplished
# Found 1 items.
# the 244th/257 sample is accomplished
# Found 1 items.
# the 245th/257 sample is accomplished
# Found 1 items.
# the 246th/257 sample is accomplished
# Found 1 items.
# the 247th/257 sample is accomplished
# Found 1 items.
# the 248th/257 sample is accomplished
# Found 1 items.
# the 249th/257 sample is accomplished
# Found 1 items.
# the 250th/257 sample is accomplished
# Found 1 items.
# the 251th/257 sample is accomplished
# Found 1 items.
# the 252th/257 sample is accomplished
# Found 1 items.
# the 253th/257 sample is accomplished
# Found 1 items.
# the 254th/257 sample is accomplished
# Found 1 items.
# the 255th/257 sample is accomplished
# Found 1 items.
# the 256th/257 sample is accomplished
# Found 1 items.
# the 257th/257 sample is accomplished
# CPU times: user 1h 30min 9s, sys: 6min 59s, total: 1h 37min 8s
# Wall time: 2h 57min 32s

# %%
np.savez('results\weather_data', SA= timeseries_SA, WS= timeseries_WS)

# %%
## Vietnam
# latitude = 10.5
# longitude = 105.2
# buffer = 0.1
# bbox = [longitude - buffer, latitude - buffer, longitude + buffer, latitude + buffer]
# year = "2022"
# months = {
#     "January": "01",
#     "February": "02",
#     "March": "03",
#     "April": "04",
#     "May": "05",
#     "June": "06",
#     "July": "07"
# }
# items = dict()
# months.items()

# %%
## Fetch the collection of interest and print available items
# for name, number in months.items():
#     datetime = f"{year}-{number}"
#     search = catalog.search(
#         collections=["modis-11A1-061"],
#         bbox=bbox,
#         datetime=datetime,
#     )
#     items[name] = search.get_all_items()[0]
#
# print(items)

# %%
# data_Day = odc.stac.load(
#     items.values(),
#     crs="EPSG:3857",
#     bands="LST_Day_1km",
#     resolution=500,
#     bbox=bbox,
# )
#
# raster_Day = items["March"].assets["LST_Day_1km"].extra_fields["raster:bands"]
# data_Day = data_Day["LST_Day_1km"] * raster_Day[0]["scale"]
# data_Day
